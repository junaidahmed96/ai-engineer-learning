# %% [markdown]
# Models Integration with OpenAI , Google Gemini , GROQ

# %%
import os 
from dotenv import  load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x1115cbf70>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11155a2e0>, root_client=<openai.OpenAI object at 0x1115cb190>, root_async_client=<openai.AsyncOpenAI object at 0x11169fe80>, model_name='gpt-4.1', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True)

# %%
respone=model.invoke("How are you my Friend ")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 respone=model.invoke("How are you my Friend ")
#
# File ~/langchain_project/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
#     399             tags=config.get("tags"),
#     400             metadata=config.get("metadata"),
#     401             run_name=config.get("run_name"),
# ...

# %% [markdown]
# OLLAMA Model Integeration

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="llama3.2"
)

response = model.invoke("How are you my friend?")

response.content
# Out:
# "I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help you with any questions or topics you'd like to discuss! How about you? How's your day going?"

# %% [markdown]
# GOOGLE Gemini Model Integeration

# %%
import os 
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

model=init_chat_model("google_genai:gemini-3.5-flash-lite")

response = model.invoke("Why do parrots talk?")

print(response.content)
# Out:
# Parrots talk primarily because they are **social learners** and use vocal mimicry to build relationships, identify family members, and claim territory.
#
# In the wild, parrots don't talk just for fun; their survival depends on fitting in. Here is a breakdown of the main reasons why parrots talk, both in the wild and as pets:
#
# ### 1. Social Bonding and Flocking
# Parrots are extremely social animals that live in flocks. In the wild, baby parrots learn the specific calls and dialects of their parents and flock mates. This helps them stay connected, recognize who is in the family, and strengthen social bonds.
#
# ### 2. Survival and Territorial Defense
# Wild parrots use sound to communicate danger, find mates, and defend their territory. They have to be very good listeners and mimics to survive in dense jungle environments where visual contact is difficult.
#
# ### 3. High Intelligence and Brain Structure
# ...

# %%
## ChatOpen AI

from langchain_openai import ChatOpenAI

model = ChatOpenAI(
    model="gpt-4.1"
)

response = model.invoke("How are you my friend?")

response.content
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[13], line 9
#       3 from langchain_openai import ChatOpenAI
#       5 model = ChatOpenAI(
#       6     model="gpt-4.1"
#       7 )
# ----> 9 response = model.invoke("How are you my friend?")
#      11 response.content
#
# File ~/langchain_project/.venv/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:395, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     383 @override
#     384 def invoke(
#     385     self,
#    (...)
#     390     **kwargs: Any,
#     391 ) -> BaseMessage:
#     392     config = ensure_config(config)
#     393     return cast(
#     394         "ChatGeneration",
# --> 395         self.generate_prompt(
#     396             [self._convert_input(input)],
#     397             stop=stop,
#     398             callbacks=config.get("callbacks"),
# ...

# %%
## ChatGoogleGenerative AI

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash-lite"
)

response = model.invoke("How are you my friend?")

response.content
# Out:
# "I'm doing well, thank you for asking! How are you doing today, and how can I help you?"

# %% [markdown]
# GROQ Model Integeration

# %%
import os 

from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:qwen/qwen3.8-27b")

response = model.invoke("WHY are you here ???")
response.content
# Out:
# 'I am here to help **you**.\n\nThink of me as a highly versatile digital companion. My purpose is to assist you with a wide variety of tasks, such as:\n\n*   **Answering questions** – from factual queries to complex explanations.\n*   **Creative work** – helping with writing, brainstorming, coding, or problem-solving.\n*   **Analysis** – summarizing information, analyzing data, or offering different perspectives on a topic.\n*   **Clarification** – breaking down difficult concepts into simpler terms.\n\nUltimately, my existence is focused on being a useful, reliable, and safe tool for you. So, how can I help you today? 😊'

# %%
import os
from groq import Groq

client = Groq(api_key=os.getenv("GROQ_API_KEY"))

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# meta-llama/llama-prompt-guard-2-86m
# qwen/qwen3.6-27b
# allam-2-7b
# canopylabs/orpheus-arabic-saudi
# openai/gpt-oss-120b
# openai/gpt-oss-safeguard-20b
# whisper-large-v3-turbo
# whisper-large-v3
# openai/gpt-oss-20b
# meta-llama/llama-prompt-guard-2-22m
# groq/compound
# canopylabs/orpheus-v1-english
# qwen/qwen3.8-27b
# groq/compound-mini
