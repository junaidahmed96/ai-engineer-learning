# %% [markdown]
# Models Integration with OpenAI , Google Gemini , GROQ

# %%
import os 
from dotenv import  load_dotenv
load_dotenv()

os.envrion["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.envrion["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.envrion["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
